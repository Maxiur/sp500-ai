# %%
import yfinance as yf
sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period="max")
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
# 2025-07-11 00:00:00-04:00  6255.680176  6269.439941  6237.600098  6259.750000
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-06-27 00:00:00-04:00', '2025-06-30 00:00:00-04:00',
#                '2025-07-01 00:00:00-04:00', '2025-07-02 00:00:00-04:00',
#                '2025-07-03 00:00:00-04:00', '2025-07-07 00:00:00-04:00',
#                '2025-07-08 00:00:00-04:00', '2025-07-09 00:00:00-04:00',
#                '2025-07-10 00:00:00-04:00', '2025-07-11 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24497, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
# 2025-07-11 00:00:00-04:00  6255.680176  6269.439941  6237.600098  6259.750000
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
# 2025-07-11 00:00:00-04:00  6255.680176  6269.439941  6237.600098  6259.750000
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
# 2025-07-11 00:00:00-04:00  6255.680176  6269.439941  6237.600098  6259.750000
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "High", "Low", "Open", "Volume"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
RandomForestClassifier(min_samples_split=100, random_state=1)

from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5609756097560976

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

def backtest(data, model, predictors, start=2500, step=250):
    all_predictios = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictios.append(predictions)
    return pd.concat(all_predictios)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3726
# 1    2721
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5306872473355384

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536529
# 0    0.463471
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_18932\3685019207.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
# C:\Users\mateu\AppData\Local\Temp\ipykernel_18932\3685019207.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-07-03 00:00:00-04:00  6246.459961  6284.649902  6246.459961  6279.350098
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
#
# ...

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1997-11-26 00:00:00-05:00   950.820007   956.469971   950.820007   951.640015
# 1997-11-28 00:00:00-05:00   951.640015   959.130005   951.640015   955.400024
# 1997-12-01 00:00:00-05:00   955.400024   974.770020   955.400024   974.770020
# 1997-12-02 00:00:00-05:00   974.780029   976.200012   969.830017   971.679993
# 1997-12-03 00:00:00-05:00   971.679993   980.809998   966.159973   976.770020
# ...                                ...          ...          ...          ...
# 2025-07-03 00:00:00-04:00  6246.459961  6284.649902  6246.459961  6279.350098
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
#
# ...

# %%
model = RandomForestClassifier(n_estimators=500, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds <= .6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1997-11-26 00:00:00-05:00   950.820007   956.469971   950.820007   951.640015
# 1997-11-28 00:00:00-05:00   951.640015   959.130005   951.640015   955.400024
# 1997-12-01 00:00:00-05:00   955.400024   974.770020   955.400024   974.770020
# 1997-12-02 00:00:00-05:00   974.780029   976.200012   969.830017   971.679993
# 1997-12-03 00:00:00-05:00   971.679993   980.809998   966.159973   976.770020
# ...                                ...          ...          ...          ...
# 2025-07-03 00:00:00-04:00  6246.459961  6284.649902  6246.459961  6279.350098
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
#
# ...

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    3922
# 1.0     524
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5553435114503816

# %%
model = RandomForestClassifier(n_estimators=5000, min_samples_split=100, random_state=1)

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1997-11-26 00:00:00-05:00   950.820007   956.469971   950.820007   951.640015
# 1997-11-28 00:00:00-05:00   951.640015   959.130005   951.640015   955.400024
# 1997-12-01 00:00:00-05:00   955.400024   974.770020   955.400024   974.770020
# 1997-12-02 00:00:00-05:00   974.780029   976.200012   969.830017   971.679993
# 1997-12-03 00:00:00-05:00   971.679993   980.809998   966.159973   976.770020
# ...                                ...          ...          ...          ...
# 2025-07-03 00:00:00-04:00  6246.459961  6284.649902  6246.459961  6279.350098
# 2025-07-07 00:00:00-04:00  6259.040039  6262.069824  6201.000000  6229.979980
# 2025-07-08 00:00:00-04:00  6234.029785  6242.700195  6217.750000  6225.520020
# 2025-07-09 00:00:00-04:00  6243.330078  6269.160156  6231.430176  6263.259766
# 2025-07-10 00:00:00-04:00  6266.799805  6290.220215  6251.439941  6280.459961
#
# ...

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4044
# 1.0     402
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5422885572139303

# %%
X = sp500[new_predictors].copy().iloc[1000:]
y = sp500["Target"].copy().iloc[1000:]
model = RandomForestClassifier(n_estimators=5000, min_samples_split=100, random_state=1)
model.fit(X, y)
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=5000, random_state=1)

# %%
precision_score(y, model.predict(X))
# Out:
# 0.6986046511627907

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
 precision_score(y, model.predict(X))
# Out:
# 0.7006993006993008

# %%
import joblib
joblib.dump(model, "random_forest_model.joblib")
# Out:
# ['random_forest_model.joblib']

# %%
predictions.to_csv("predictions.csv")
sp500.to_csv("sp500_with_features.csv")
